# %%
import pandas as pd
import sys, os
project_root = os.path.abspath(os.path.join(os.getcwd(), "../"))
sys.path.append(project_root)
from src.data_analysis import ComplaintDeliverableEDA

# %%
# 1. Load the Consumer Complaints dataset
# Note: Ensure the file path matches your project structure
df = pd.read_csv('../data/raw/complaints.csv')
# Out:
# C:\Users\Birhanu Matebe\AppData\Local\Temp\ipykernel_12948\2277211931.py:3: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../data/raw/complaints.csv')

# %%
analysis = ComplaintDeliverableEDA(df)
analysis.run_deliverable_analysis()
# Out:
# [1/3] Analyzing Product Distribution...
#                                                       Count  Percentage
# Product
# Credit reporting or other personal consumer rep...  4834855       50.31
# Credit reporting, credit repair services, or ot...  2163857       22.52
# Debt collection                                      799197        8.32
# Mortgage                                             422254        4.39
# Checking or savings account                          291178        3.03
# Credit card                                          226686        2.36
# Credit card or prepaid card                          206369        2.15
# Money transfer, virtual currency, or money service   145066        1.51
# Credit reporting                                     140429        1.46
# Student loan                                         109717        1.14
# Bank account or service                               86205        0.90
# ...
