# %%
import pandas as pd
import sys, os
project_root = os.path.abspath(os.path.join(os.getcwd(), "../"))
sys.path.append(project_root)
from src.data_profiling import ComplaintProfiling

# %%
df =pd.read_csv("../data/raw/complaints.csv")
# Out:
# C:\Users\Birhanu Matebe\AppData\Local\Temp\ipykernel_14608\3047717894.py:1: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df =pd.read_csv("../data/raw/complaints.csv")

# %%
df.head()
# Out:
#   Date received                                            Product  \
# 0    2025-06-20  Credit reporting or other personal consumer re...
# 1    2025-06-20                                    Debt collection
# 2    2025-06-20  Credit reporting or other personal consumer re...
# 3    2025-06-20  Credit reporting or other personal consumer re...
# 4    2025-06-20  Credit reporting or other personal consumer re...
#
#                Sub-product                                 Issue  \
# 0         Credit reporting  Incorrect information on your report
# 1  Telecommunications debt     Attempts to collect debt not owed
# 2         Credit reporting           Improper use of your report
# 3         Credit reporting           Improper use of your report
# 4         Credit reporting  Incorrect information on your report
#
#                                        Sub-issue Consumer complaint narrative  \
# 0            Information belongs to someone else                          NaN
# ...

# %%
# 2. Initialize the Profiling class
profiler = ComplaintProfiling(df)

# 3. Run the analysis
# This will print the overview, stats, missing values, duplicates, and date ranges
profiler.run_all()

# Optional: Access the cleaned dataframe (with converted dates)
df_cleaned = profiler.df
# Out:
# ====== CONSUMER COMPLAINT DATA OVERVIEW ======
# Total Complaints: 9609797
# Total Features: 18
#
# Data Types Summary:
# object            15
# datetime64[ns]     2
# int64              1
# Name: count, dtype: int64
# First 3 Rows:
#   Date received                                            Product  \
# 0    2025-06-20  Credit reporting or other personal consumer re...
# 1    2025-06-20                                    Debt collection
# 2    2025-06-20  Credit reporting or other personal consumer re...
#
#                Sub-product                                 Issue  \
# 0         Credit reporting  Incorrect information on your report
# 1  Telecommunications debt     Attempts to collect debt not owed
# 2         Credit reporting           Improper use of your report
#
#                                        Sub-issue Consumer complaint narrative  \
# 0            Information belongs to someone else                          NaN
# ...

# %%
df.sample(40)
# Out:
#         Date received                                            Product  \
# 7455996    2022-02-16  Credit reporting, credit repair services, or o...
# 5483256    2021-11-17  Credit reporting, credit repair services, or o...
# 335561     2025-04-30                                    Debt collection
# 6170785    2020-09-05  Credit reporting, credit repair services, or o...
# 3692622    2024-05-18  Credit reporting or other personal consumer re...
# 2048447    2025-01-11  Credit reporting or other personal consumer re...
# 9332216    2016-10-25                                        Credit card
# 4665326    2020-10-06  Credit reporting, credit repair services, or o...
# 1941842    2025-03-19  Credit reporting or other personal consumer re...
# 4076842    2023-09-06  Credit reporting or other personal consumer re...
# 479662     2025-03-26  Credit reporting or other personal consumer re...
# 7350669    2021-11-04  Credit reporting, credit repair services, or o...
# ...
