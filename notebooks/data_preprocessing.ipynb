# %%
import pandas as pd
import sys, os
import nltk
# These are the 3 specific things your code is looking for
nltk.download('punkt_tab')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4') # Required for WordNet to work properly
project_root = os.path.abspath(os.path.join(os.getcwd(), "../"))
sys.path.append(project_root)
from src.data_preprocessing import ComplaintFinalProcessor
# Out:
# [nltk_data] Downloading package punkt_tab to C:\Users\Birhanu
# [nltk_data]     Matebe\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\Birhanu
# [nltk_data]     Matebe\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to C:\Users\Birhanu
# [nltk_data]     Matebe\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to C:\Users\Birhanu
# [nltk_data]     Matebe\AppData\Roaming\nltk_data...

# %%
df = pd.read_csv('../data/raw/complaints.csv')
# Out:
# C:\Users\Birhanu Matebe\AppData\Local\Temp\ipykernel_3748\2154497876.py:1: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../data/raw/complaints.csv')

# %%
processor = ComplaintFinalProcessor(df)

df_cleaned = processor.run_cleaning_pipeline()

# 5. Display the results
print("\n--- Preprocessing Results ---")
print(f"Final count after cleaning: {len(df_cleaned)}")
print("\nSample of Original vs. Normalized Text:")
display(df_cleaned[['Consumer complaint narrative', 'normalized_text']].head())
df_cleaned.to_csv('../data/processed/complaints_processed_for_rag.csv', index=False)
print("\n✓ Cleaned data saved to 'complaints_processed_for_rag.csv'")
# Out:
# Starting Final Preprocessing Pipeline...
# -> Stripping Noise (URLs, Emails, Phones, HTML)...
# -> Applying Tokenization, Stopword removal, and Lemmatization...
# ✓ Pipeline Complete. 190738 records fully cleaned and ready.
#
# --- Preprocessing Results ---
# Final count after cleaning: 190738
#
# Sample of Original vs. Normalized Text:
#                             Consumer complaint narrative  \
# 12237  A XXXX XXXX card was opened under my name by a...
# 13280  Dear CFPB, I have a secured credit card with c...
# 13506  I have a Citi rewards cards. The credit balanc...
# 13955  b'I am writing to dispute the following charge...
# 14249  Although the account had been deemed closed, I...
#
#                                          normalized_text
# 12237  card open name fraudster receive notice accoun...
# 13280  dear cfpb secure credit card citibank change u...
# 13506  citi reward card credit balance issue 840000 r...
# 13955  bi write dispute follow charge citi credit car...
# ...

# %%
df_cleaned.sample(10)
# Out:
#         Date received                      Product  \
# 3353898    2023-10-09                  Credit card
# 3503699    2024-12-01                  Credit card
# 3987151    2021-08-07  Credit card or prepaid card
# 5944222    2024-03-18                  Credit card
# 2649810    2023-07-07  Credit card or prepaid card
# 4925868    2023-08-01  Credit card or prepaid card
# 7687557    2016-04-15                  Credit card
# 5677372    2022-04-04  Credit card or prepaid card
# 4114102    2024-10-01                  Credit card
# 7416338    2020-06-02  Credit card or prepaid card
#
#                                         Sub-product  \
# 3353898  General-purpose credit card or charge card
# 3503699  General-purpose credit card or charge card
# 3987151  General-purpose credit card or charge card
# 5944222  General-purpose credit card or charge card
# 2649810  General-purpose credit card or charge card
# 4925868  General-purpose credit card or charge card
# ...
